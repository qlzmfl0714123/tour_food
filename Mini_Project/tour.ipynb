# %%
import requests

def search_google_places(query, api_key):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': f"{query} 관광지",   
        'language': 'ko',
        'key': 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
    }
    res = requests.get(url, params=params)

    if res.status_code != 200:
        print("API 요청 실패:", res.status_code)
        return []

    data = res.json()

    results = data.get('results', [])
    if not results:
        print("검색 결과 없음.")
        return []

    print(f"\n '{query}' 지역의 추천 관광지 리스트 ({len(results)}개):\n")
    for i, place in enumerate(results, 1):
        name = place.get('name', '이름 없음')
        addr = place.get('formatted_address', '주소 없음')
        rating = place.get('rating', '평점 없음')
        print(f"{i}. {name} ({rating})\n  {addr}\n")

    return results

API_KEY = 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
user_input = input("가고 싶은 지역을 입력하세요 : ")
search_google_places(user_input, API_KEY)
# Out:
#  '경기도' 지역의 추천 관광지 리스트 (20개):
#
# 1. 광명동굴 (4.3)
#   대한민국 경기도 광명시 가학로85번길 142
#
# 2. 피아노폭포 (3.8)
#   대한민국 경기도 남양주시 화도읍 폭포로 562
#
# 3. 팔당유원지 (4.2)
#   대한민국 경기도 남양주시 와부읍 팔당리
#
# 4. 두물머리 (4.3)
#   대한민국 경기도 양평군 양서면 두물머리길
#
# 5. 헤세의 정원 (4.1)
#   대한민국 경기도 양주시 장흥면 호국로550번길 107 KR
#
# 6. 헤이리 예술마을 (4)
#   대한민국 경기도 파주시 탄현면 헤이리마을길 82-105
#
# 7. 한국민속촌 (4.4)
#   대한민국 경기도 용인시 기흥구 민속촌로 90
#
# 8. 바다향기수목원 (4.2)
#   대한민국 경기도 안산시 단원구 선감동 대부황금로 399
#
# 9. 장흥조각공원 (4.1)
#   대한민국 경기도 양주시 장흥면 권율로 193
#
# 10. 마장호수 출렁다리 (4.3)
#   대한민국 경기도 파주시 광탄면 기산리 481-1
#
# 11. 용인농촌테마파크 (4.4)
#   대한민국 경기도 용인시 원삼면 농촌파크로 80-1
#
# 12. 청계산 도깨비 도로 (3.7)
#   대한민국 경기도 의왕시 청계동 152-1
#
# 13. 오이도포구 해양관광단지 (4)
#   대한민국 경기도 시흥시 정왕동 1985
#
# 14. 팔당 물안개공원 (4.2)
#   대한민국 경기도 광주시 남종면 귀여리
#
# 15. 국립수목원 (4.5)
#   대한민국 경기도 포천시 소흘읍 광릉수목원로 415
#
# 16. 관곡지 (3.9)
#   대한민국 경기도 시흥시 하중동 208
#
# 17. 오이도 선사유적공원 (4.3)
#   대한민국 경기도 시흥시 정왕1동 183번지
#
# 18. 물의 정원 (4.4)
#   대한민국 경기도 남양주시 조안면 북한강로 398
#
# 19. 지동 벽화마을 (4.1)
#   대한민국 경기도 수원시 팔달구 지동 271-156
#
# 20. 용인대장금파크 (4.4)
#   대한민국 경기도 용인시 처인구 백암면 용천리 778-1
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 경기도
#     'width': 4000}],
#   'place_id': 'ChIJUSM8XqVaezUR65ah4DglaD4',
#   'plus_code': {'compound_code': '7459+H6 용인시 경기도',
#    'global_code': '8Q997459+H6'},
#   'rating': 4.4,
#   'reference': 'ChIJUSM8XqVaezUR65ah4DglaD4',
#   'types': ['tourist_attraction',
#    'amusement_park',
#    'museum',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 15869},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 경기도 안산시 단원구 선감동 대부황금로 399',
#   'geometry': {'location': {'lat': 37.22514080000001, 'lng': 126.6466979},
#    'viewport': {'northeast': {'lat': 37.22649062989272,
#      'lng': 126.6480477298927},
#     'southwest': {'lat': 37.22379097010728, 'lng': 126.6453480701072}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png',
#   'icon_background_color': '#4DB546',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet',
#   'name': '바다향기수목원',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 9000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116794297431678234068">아삭</a>'],
#     'photo_reference': 'ATKogpdKL2H-TESnwq_CbbZXczQwh6zS1CsN_uquc4qjFR9tuTQyyg9aNwc4UZlzuYyx0fi-9EkcW9uAd5jLTcw3Ah2BiLuPx_TukvGjxfzyVhD4M61BvvVioNp8GJR-3QD-piLX2Z7xmaPadVodSWQh-WB-_HxnHnWNku9wHDLvxgUrKT6eGMy9-D1VPLqTVf8LfA2yeXtGW2sMVHZTcOganNqZkmxWhThTYlFp7SW1uKNOTDJYs7Qc48JWYxq6dBsTZGNOL-R1EJABWzt96OZsWsoSpf9W_dRExsj7oPliOl5P8Hf_0wxsMSmIvfeXq9ACDZw966tS9evYFWrRfy8m2-rCILBsuUcDb6GqyV71MG8zC53w-YNbAKZEKys7uxl1gKXjGee3z-pDVso4WXpMBAfQFBpkdExQrEshcRKJvqwRieVfjLgWVvf_iKyzT4ZK0lzdjzJfNkhaaqn0mJQecCEjhxSXwHrSh9AMQz9xdOSA_3ypqh2f0aZ1ifYjZmUmmQSGke7WEwTH9ptSsX9TsaM4cl11-mc7w-bEAG4-GNabFVmL8uv3kTZT5XooLiEtU3DMYio8',
#     'width': 12000}],
#   'place_id': 'ChIJMas8glEKezURXtL_8hVv_-U',
#   'plus_code': {'compound_code': '6JGW+3M 안산시 경기도',
#    'global_code': '8Q986JGW+3M'},
#   'rating': 4.2,
#   'reference': 'ChIJMas8glEKezURXtL_8hVv_-U',
#   'types': ['tourist_attraction',
#    'park',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 1844},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 경기도 양주시 장흥면 권율로 193',
#   'geometry': {'location': {'lat': 37.7311252, 'lng': 126.9488011},
#    'viewport': {'northeast': {'lat': 37.73247502989272,
#      'lng': 126.9501509298927},
#     'southwest': {'lat': 37.72977537010728, 'lng': 126.9474512701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png',
#   'icon_background_color': '#4DB546',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet',
#   'name': '장흥조각공원',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/
#     'width': 5312}],
#   'place_id': 'ChIJcQ7-_SZfezURas4IGevvoO0',
#   'plus_code': {'compound_code': '92VG+JX 의왕시 경기도',
#    'global_code': '8Q9992VG+JX'},
#   'rating': 3.7,
#   'reference': 'ChIJcQ7-_SZfezURas4IGevvoO0',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 76},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 경기도 시흥시 정왕동 1985',
#   'geometry': {'location': {'lat': 37.348535, 'lng': 126.6889438},
#    'viewport': {'northeast': {'lat': 37.34988482989272,
#      'lng': 126.6902936298927},
#     'southwest': {'lat': 37.34718517010728, 'lng': 126.6875939701072}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': '오이도포구 해양관광단지',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110170872010741077358">봤스메</a>'],
#     'photo_reference': 'ATKogpcNuZWMIpeE2AAVTFA-3W4TuJKU1LQhM_d3T1VwHK7Ns3SmRp8psPrlTTpzltI_J6p6iwKdecTKM28LdM6beX7pcaYxxzmZ0Bq7afC9h4FmqXQZsERZYzQlM9WgB_A6PLfTxtN_RvQ8EjNd8z_8QvV2hGLISYDlieZc07-OS9GwHuH8QdTIjKWnBSH-59iwS5sPKYkHHTB4lIJaa8LTH3H9qy7ADxZctwOxxkoinmrd5AD-IDR8BH6QojQLFoHvkqkk64ZFI6HFZ-fhifG-cZwFgbnOkrO1tElfgZy3m2rQx8ClS1aTUZbh-_ILrqvbI2QOck12fpOSOsFminaa16oxR4qdIUV9iXLFx1slNrHmAP38GoLFU7xe1eirdTrdiY2fBt1hYRdWdUWN3-BaasGV5P_QF09cvSY_-3jk6jIWzDsKhGXLg8Wqp0cnr1K8WSphmD6QutqZvoHFgPLms6GrKXzPWnJ9lXkF99zonpUZYwVOyqd-qH0SqeG61LZ33SbHShr_mceoniPXBJlN4y7U2F_AKd88IkvoGDmwl4SRSmrTLUZR-tnHKJK3I74vBqGwmLCriFBz6Q',
#     'width': 3024}],
#   'place_id': 'ChIJF0MJvsl2ezURtD_OazSBUzo',
#   'plus_code': {'compound_code': '8MXQ+CH 시흥시 경기도',
#    'global_code': '8Q988MXQ+CH'},
#   'rating': 4,
#   'reference': 'ChIJF0MJvsl2ezURtD_OazSBUzo',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 923},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 경기도 광주시 남종면 귀여리',
#   'geometry': {'location': {'lat': 37.5103926, 'lng': 127.3151312},
#    'viewport': {'northeast': {'lat': 37.51174242989273,
#      'lng': 127.3164810298927},
#     'southwest': {'lat': 37.50904277010729, 'lng': 127.3137813701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png',
#   'icon_background_color': '#4DB546',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet',
#   'name': '팔당 물안개공원',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/
xnMsfpASltS2jz0nQu8RJU9WA7ImF6Pwg7xUTVTVJtAgboWChbYD_LMpwr9PWhD3sG3JMSyYjkcMz805IT4gaKwCQ4OMcPz85CAD8GAT9c-kzlovj-UN16DZpPT--h6nLrHmhdsS87MrA2-VrpEimD4SSdk8yTxdFdwuAl0IQ0_Mf7St9id_7OCya52Zf7AuM8PGC2YSgE_WqozStIG8Ac_p_5pTuRuAfwn8O8JN8NIQ6HFr7KY8Y58gtKHz5qeIw',
#     'width': 4000}],
#   'place_id': 'ChIJD90kscp2ezURWqRN1CSUfhI',
#   'plus_code': {'compound_code': '8MVW+26 시흥시 경기도',
#    'global_code': '8Q988MVW+26'},
#   'rating': 4.3,
#   'reference': 'ChIJD90kscp2ezURWqRN1CSUfhI',
#   'types': ['tourist_attraction',
#    'park',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 599},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 경기도 남양주시 조안면 북한강로 398',
#   'geometry': {'location': {'lat': 37.5568605, 'lng': 127.3149937},
#    'viewport': {'northeast': {'lat': 37.55821032989272,
#      'lng': 127.3163435298927},
#     'southwest': {'lat': 37.55551067010728, 'lng': 127.3136438701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png',
#   'icon_background_color': '#4DB546',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet',
#   'name': '물의 정원',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2268,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102335088819018008145">임연숙</a>'],
#     'photo_reference': 'ATKogpeh1gGAWwUekyGDp5JD6yRCmIf_ZRTwBunPaudGtuwp2_9ABLjslm-aRJ_SXkMT_XEbrV532l_50MtNZW-yt1rBzVTKEl6bbMqq0ZR8fcH1_wyJBcYALmTwl1LHRtq5ZueOjAlLLY6CGgLgfRQWz6QrzvEKU7y5CjW_zzR5TG9aGKPR1lpvLwt4mPs_iI4_gy6GzDi2SbMYo6AkmP8VdstUL94wlidRUhV8shZOc3sajpXUi63UIl5zFjztd_ns0j8ORx75kNRBBrXrLx_FavzqEYmCKgXOh-Ql_ion9DP6wh9BcY2WsuFgQx0udJeGLg62Jh0rgVKfTYgQPC2sQ3rR2wBH8LJr52WoD-fS2C8Vq9AcRUQPgQlGvSpB6RVY1liluVbt2Cm7qbcUFd_9j2j2UIaA41BuY2I4-a9wh9esMsewqkKyz-W21XyHOOQ0pPsVNT7d7de3ZYXaCdYYLBIfgeoHNtOXeeTlC68qy_EbUuomM98ZZjsRG4EdcYEllnrQdKsu76SteZ4U3sBZKvXSz-w_CV6bXfWb_YjcxJog7QlzuKI6MJ5yYcH59TlkHORcCsZb6-bFlA',
#     'width': 4032}],
#   'place_id': 'ChIJ_f_z2LNMYzURF1qdzBo59WA',
#   'plus_code': {'compound_code': 'H847+PX 남양주시 경기도',
#    'global_code': '8Q99H847+PX'},
#   'rating': 4.4,
#   'reference': 'ChIJ_f_z2LNMYzURF1qdzBo59WA',
#   'types': ['tourist_attraction',
#    'park',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 4412},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '대한민국 경기도 수원시 팔달구 지동 271-156',
#   'geometry': {'location': {'lat': 37.2810841, 'lng': 127.0229383},
#    'viewport': {'northeast': {'lat': 37.28243392989272,
#      'lng': 127.0242881298927},
#     'southwest': {'lat': 37.27973427010727, 'lng': 127.0215884701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name':

#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1212}]

# %%
import requests

def search_google_places(query, api_key):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': f"{query} 관광지",
        'language': 'ko',
        'key': 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
    }
    res = requests.get(url, params=params)
    if res.status_code != 200:
        print("API 요청 실패:", res.status_code)
        return []
    return res.json().get('results', [])


def search_kakao_restaurants(lat, lon, api_key):
    url = "https://dapi.kakao.com/v2/local/search/keyword.json"
    headers = {"Authorization": f"{'KakaoAK 7659c6478eec0d513fc4881bbcd44c2c'}"}
    params = {
        'query': '맛집',
        'x': lon,
        'y': lat,
        'radius': 3000,
        'size': 10
    }
    res = requests.get(url, headers=headers, params=params)
    if res.status_code != 200:
        print("카카오 API 실패:", res.status_code)
        return []
    return res.json().get('documents', [])

# %%
import requests

def search_google_places(query, api_key):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': query + " 관광지",
        'language': 'ko',
        'key': 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
    }
    res = requests.get(url, params=params)
    if res.status_code != 200:
        print("Google API 실패:", res.status_code)
        return []
    return res.json().get('results', [])

def search_kakao_restaurants(lat, lon, api_key, page=1):
    url = "https://dapi.kakao.com/v2/local/search/category.json"
    headers = {"Authorization": api_key}
    params = {
        'category_group_code': 'FD6',
        'x': str(lon),
        'y': str(lat),
        'radius': 3000,
        'page': page,
        'size': 15,
        'sort': 'distance'
    }
    res = requests.get(url, headers=headers, params=params)
    if res.status_code != 200:
        print("카카오 API 실패:", res.status_code)
        print("응답 내용:", res.text)
        return []

    if page == 1:
        print(" 전체 맛집 수 (API 기준):", res.json()['meta']['total_count'])
    return res.json().get('documents', [])


GOOGLE_API_KEY = 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
KAKAO_API_KEY = 'KakaoAK 7659c6478eec0d513fc4881bbcd44c2c'

region = input("여행 지역을 입력하세요 (예: 강원도): ")
places = search_google_places(region, GOOGLE_API_KEY)

if not places:
    print("해당 지역의 관광지를 찾을 수 없습니다.")
    exit()

print(f"\n'{region}'의 추천 관광지 목록:")
for i, p in enumerate(places, 1):
    print(f"{i}. {p['name']} - {p.get('formatted_address', '주소 없음')}")

idx = int(input("\n몇 번 관광지를 선택할까요? ")) - 1
selected = places[idx]
lat = selected['geometry']['location']['lat']
lon = selected['geometry']['location']['lng']
print(f"\n선택한 관광지: {selected['name']}")

restaurants = search_kakao_restaurants(lat, lon, KAKAO_API_KEY)

print("\n 주변 맛집 목록 (정상 데이터만 출력):")

valid_restaurants = [
    r for r in restaurants
    if r.get('place_name') and r.get('road_address_name')
]

if not valid_restaurants:
    print("⚠️ 표시할 수 있는 맛집 정보가 없습니다.")
else:
    for i, r in enumerate(valid_restaurants, 1):
        print(f"{i}. {r['place_name']} ({r['distance']}m)\n   {r['road_address_name']} / ☎ {r.get('phone', '정보 없음')}")
# Out:
# '강원도'의 추천 관광지 목록:
# 1. 낙산사 - 대한민국 강원특별자치도 양양군 강현면 낙산사로 100
# 2. 묵호등대 - 대한민국 강원특별자치도 동해시 해맞이길 289 묵호항로표지관리소
# 3. 무릉계곡 관광지 - 대한민국 강원특별자치도 동해시 삼화로 538
# 4. 구곡폭포관광지 - 대한민국 강원특별자치도 춘천시 남산면 강촌리
# 5. 간현관광지(소금산그랜드밸리) - 대한민국 강원특별자치도 원주시 지정면 소금산길 12
# 6. 추암 촛대바위 - 대한민국 강원특별자치도 동해시 촛대바위길 28
# 7. 무릉별유천지 - 대한민국 강원특별자치도 동해시 삼화로 380
# 8. 화암동굴 - 대한민국 강원특별자치도 정선군 화암면 화암리 산248
# 9. 속초등대 - 대한민국 강원특별자치도 속초시 영랑동 영금정로5길 8-28
# 10. 아우라지 관광지 - 대한민국 강원특별자치도 정선군 여량면 아우라지길 69
# 11. 공지천 유원지 - 대한민국 강원특별자치도 춘천시 근화동
# 12. 도째비골 스카이밸리 - 대한민국 강원특별자치도 동해시 묵호진동 2-109
# 13. 경포호(鏡浦湖) - 대한민국 강원특별자치도 강릉시 저동 94
# 14. 천학정 - 대한민국 강원특별자치도 고성군 토성면 교암리 177-1
# 15. 능파대 - 대한민국 강원특별자치도 고성군 죽왕면 문암진리
# 16. 하조대 - 대한민국 강원특별자치도 양양군 현북면 하광정리 산3
# 17. 초곡 용굴촛대바위길 - 대한민국 강원특별자치도 삼척시 근덕면 초곡리 20-42
# 18. 춘천물레길 - 대한민국 강원특별자치도 춘천시 송암동 644-23
# 19. 몰운대 - 대한민국 강원특별자치도 정선군 화암면 몰운리 산43-1
# 20. 영진해변 - 대한민국 강원특별자치도 강릉시 연곡면
#
# 선택한 관광지: 낙산사
#  전체 맛집 수 (API 기준): 133
#
#  주변 맛집 목록 (정상 데이터만 출력):
# 1. 교동마카롱 낙산점 (270m)
#    강원특별자치도 양양군 강현면 낙산사로 73 / ☎
# 2. 비치스넥코너 (272m)
#    강원특별자치도 양양군 강현면 낙산사로 73 / ☎
# 3. 광주빛고을식당 (376m)
#    강원특별자치도 양양군 강현면 낙산사로 47 / ☎ 033-672-3019
# 4. 만석치킨호프 (386m)
#    강원특별자치도 양양군 강현면 낙산사로27번길 11-6 / ☎
# 5. 충청도깜둥이네횟집 (390m)
#    강원특별자치도 양양군 강현면 낙산사로 54-20 / ☎ 010-5368-2586
# 6. 대한민국석형횟집 (391m)
#    강원특별자치도 양양군 강현면 낙산사로 54-20 / ☎
# 7. 백씨네 (393m)
#    강원특별자치도 양양군 강현면 낙산사로 54-20 / ☎ 010-4936-2865
# 8. 바다이야기 (393m)
#    강원특별자치도 양양군 강현면 낙산사로 54-20 / ☎ 010-887-1736
# 9. 석형횟집 (393m)
#    강원특별자치도 양양군 강현면 낙산사로 54-20 / ☎
# 10. 낙산어촌계활어회센타 (394m)
#    강원특별자치도 양양군 강현면 낙산사로 54-20 / ☎
# 11. 혜란석형 대한민국횟집 (394m)
#    강원특별자치도 양양군 강현면 낙산사로 54-20 / ☎ 033-672-6207
# 12. 충청도혜숙이네횟집 (395m)
#    강원특별자치도 양양군 강현면 낙산사로 54-20 / ☎ 010-6378-8999
# 13. 양씨네횟집 (395m)
#    강원특별자치도 양양군 강현면 낙산사로 54-20 / ☎ 010-6376-4620
# 14. 머구리횟집 (395m)
#    강원특별자치도 양양군 강현면 낙산사로 54-20 / ☎
# 15. 송이와국진이네 (395m)
#    강원특별자치도 양양군 강현면 낙산사로 54-20 / ☎ 033-672-0901

# %%
import requests


def search_google_places(query, api_key):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': query + " 관광지",
        'language': 'ko',
        'key': api_key
    }
    res = requests.get(url, params=params)
    if res.status_code != 200:
        print("Google API 실패:", res.status_code)
        return []
    return res.json().get('results', [])


def search_kakao_restaurants(lat, lon, api_key, pages=3):
    url = "https://dapi.kakao.com/v2/local/search/category.json"
    headers = {"Authorization": api_key}
    all_restaurants = []

    for page in range(1, pages + 1):
        params = {
            'category_group_code': 'FD6',   
            'x': str(lon),
            'y': str(lat),
            'radius': 3000,                
            'size': 15,
            'page': page,
            'sort': 'distance'
        }
        res = requests.get(url, headers=headers, params=params)
        if res.status_code != 200:
            print("카카오 API 실패:", res.status_code)
            print("응답 내용:", res.text)
            continue
        all_restaurants += res.json().get('documents', [])

    return all_restaurants


GOOGLE_API_KEY = 'AIzaSyAypFLkcwV_HqxLsTpU8RfkXsYeBG9vetg'
KAKAO_API_KEY = 'KakaoAK 7659c6478eec0d513fc4881bbcd44c2c'


region = input("여행 지역을 입력하세요 (예: 강원도): ")
places = search_google_places(region, GOOGLE_API_KEY)

if not places:
    print("해당 지역의 관광지를 찾을 수 없습니다.")
    exit()

print(f"\n '{region}'의 추천 관광지 목록:")
for i, p in enumerate(places, 1):
    print(f"{i}. {p['name']} - {p.get('formatted_address', '주소 없음')}")

idx = int(input("\n몇 번 관광지를 선택할까요? ")) - 1
selected = places[idx]
lat = selected['geometry']['location']['lat']
lon = selected['geometry']['location']['lng']
print(f"\n 선택한 관광지: {selected['name']}")


restaurants = search_kakao_restaurants(lat, lon, KAKAO_API_KEY, pages=5)
print(f"\n 전체 받은 맛집 수: {len(restaurants)}")


valid_restaurants = [
    r for r in restaurants
    if r.get('place_name')
]


sorted_restaurants = sorted(valid_restaurants, key=lambda x: int(x.get('distance', 99999)))


print("\n 주변 맛집 Top 10:")
for i, r in enumerate(sorted_restaurants[:10], 1):
    print(f"{i}. {r['place_name']} ({r.get('distance', '?')}m)")
    print(f"    {r.get('road_address_name', '주소 없음')} / ☎ {r.get('phone', '정보 없음')}")
    print(f"    카카오맵: {r.get('place_url', '없음')}\n")
# Out:
#  '서울'의 추천 관광지 목록:
# 1. 경복궁 - 대한민국 서울특별시 종로구 사직로 161
# 2. 청계천 - 대한민국 서울특별시 종로구
# 3. 북촌 한옥마을 - 대한민국 서울특별시 종로구 계동길
# 4. N서울타워 - 대한민국 서울특별시 용산구 남산공원길 105
# 5. 소악루 - 대한민국 서울특별시 강서구 가양동 219-7
# 6. 덕수궁 - 대한민국 서울특별시 중구 세종대로 99
# 7. 남산골한옥마을 - 대한민국 서울특별시 중구 퇴계로34길 28
# 8. 남산 공원 - 대한민국 서울특별시 중구 삼일대로 231
# 9. 광화문광장 - 대한민국 서울특별시 종로구 세종대로 172
# 10. 전쟁기념관 - 대한민국 서울특별시 용산구 이태원로 29
# 11. 국립고궁박물관 - 대한민국 서울특별시 종로구 효자로 12
# 12. 서울역사박물관 - 대한민국 서울특별시 종로구 새문안로 55
# 13. 명동거리 - 대한민국 서울특별시 중구 명동2가
# 14. 인사동 문화의 거리 - 대한민국 서울특별시 종로구 인사동
# 15. 청와대 - 대한민국 서울특별시 종로구 청와대로 1
# 16. 이화동 벽화마을 - 대한민국 서울특별시 종로구 낙산4길 49
# 17. 재미로 - 대한민국 서울특별시 중구
# 18. 고종의 길 - 대한민국 서울특별시 중구 정동 1-10
# 19. 서촌 한옥마을 - 대한민국 서울특별시 종로구 통의동 28-1
# 20. 선유도공원 - 대한민국 서울특별시 영등포구 선유로 343
#
#  선택한 관광지: 북촌 한옥마을
#
#  전체 받은 맛집 수: 75
#
#  주변 맛집 Top 10:
# 1. 막끌리죠 (40m)
#     서울 종로구 북촌로 53 / ☎
#     카카오맵: http://place.map.kakao.com/26796664
#
# 2. 너드하우스 북촌 (63m)
#     서울 종로구 북촌로8길 5 / ☎
#     카카오맵: http://place.map.kakao.com/1312827132
#
# 3. 에치엠푸드 정독 (98m)
#     서울 종로구 북촌로5길 48 / ☎
#     카카오맵: http://place.map.kakao.com/1109620086
#
# 4. 정독도서관 소담정 (98m)
#     서울 종로구 북촌로5길 48 / ☎
#     카카오맵: http://place.map.kakao.com/2141850339
#
# 5. 백년토종삼계탕 (99m)
#     서울 종로구 북촌로 41 / ☎ 02-747-5535
#     카카오맵: http://place.map.kakao.com/23259207
#
# 6. 대장장이화덕피자 (108m)
#     서울 종로구 북촌로 42-4 / ☎ 02-765-4298
#     카카오맵: http://place.map.kakao.com/8256250
#
# 7. 꽃밥에피다 북촌 (131m)
#     서울 종로구 북촌로 39 / ☎ 02-766-6272
#     카카오맵: http://place.map.kakao.com/1982377283
#
# 8. 그래인스쿠키 (139m)
#     서울 종로구 북촌로11나길 1 / ☎
#     카카오맵: http://place.map.kakao.com/1799510470
#
# 9. 국수명가 가회점 (146m)
#     서울 종로구 북촌로6길 1 / ☎ 02-744-3368
#     카카오맵: http://place.map.kakao.com/1670995405
#
# 10. 왕짱구식당 (159m)
#     서울 종로구 계동길 81 / ☎ 02-743-4300
#     카카오맵: http://place.map.kakao.com/12078581
